# %% [markdown]
# **imports**

# %%
#imports
import numpy as np
import pandas as pd

import os, gc, warnings
import random
import datetime
import warnings
import time

from tqdm.notebook import tqdm

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
import sklearn

warnings.filterwarnings('ignore')

# %% [markdown]
# **load data**

# %%
#load data
path = "E:/pasca/Documents/Test/"
train_df = pd.read_csv(path + 'train.csv')
building_df = pd.read_csv(path + 'building_metadata.csv')
weather_df = pd.read_csv(path + 'weather_train.csv')
test_df = pd.read_csv(path + 'test.csv')
weather_test_df = pd.read_csv(path + 'weather_test.csv')

# %% [markdown]
# **data understanding / visualisation**

# %%
def data_info(x, y = 1):
    #print data infonformations
    #y=timestamp(False,True)
    #y=[0,1]
    print(10*"-----")
    print(x.info())
    print(10*"-----")
    print(x.describe())
    print(10*"-----")
    print("sample:")
    print(x.sample(5))
    print(msno.matrix(x))
    if y == 0:
        print(10*"-----")
        print("timestamp start:" + str(x.timestamp.min()))
        print("timestamp end:" + str(x.timestamp.max()))
    print(10*"-----")
    print("count of missing values:")
    print(x.isnull().sum())
    print(10*"-----")
    print("percentage of missing values:")
    print(x.isna().sum()/len(x)*100)
    print(10*"-----")
    print("missing values visualized:")

# %%
#preperation for data visualisation

#copy dataframe for visualisation
train_vis_df = train_df.copy()
weather_vis_df = weather_df.copy()
test_vis_df = test_df.copy()

#set type of timestamp
train_vis_df["timestamp"] = train_vis_df["timestamp"].astype("datetime64")
test_vis_df["timestamp"] = test_vis_df["timestamp"].astype("datetime64")
weather_vis_df["timestamp"] = weather_vis_df["timestamp"].astype("datetime64")

#merge train_df & building_df
merge_vis_df = train_vis_df.merge(building_df, left_on='building_id',right_on='building_id',how='left')
merge_vis_df = merge_vis_df.merge(weather_vis_df,how='left',left_on=['site_id','timestamp'],right_on=['site_id','timestamp'])

# %%
#train_df
print("Anzahl unterschiedlicher Gebäuden: " + str(len(train_df["building_id"].value_counts())))
data_info(train_df, 0)
# Out:
# Anzahl unterschiedlicher Gebäuden: 1449
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216100 entries, 0 to 20216099
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   building_id    int64
#  1   meter          int64
#  2   timestamp      object
#  3   meter_reading  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 616.9+ MB
# None
# --------------------------------------------------
#         building_id         meter  meter_reading
# count  2.021610e+07  2.021610e+07   2.021610e+07
# mean   7.992780e+02  6.624412e-01   2.117121e+03
# std    4.269133e+02  9.309921e-01   1.532356e+05
# min    0.000000e+00  0.000000e+00   0.000000e+00
# 25%    3.930000e+02  0.000000e+00   1.830000e+01
# 50%    8.950000e+02  0.000000e+00   7.877500e+01
# 75%    1.179000e+03  1.000000e+00   2.679840e+02
# max    1.448000e+03  3.000000e+00   2.190470e+07
# --------------------------------------------------
# sample:
#           building_id  meter            timestamp  meter_reading
# 13902344           62      0  2016-09-10 15:00:00        634.781
# 14982822          503      0  2016-09-29 18:00:00         18.730
# 6738786          1011      3  2016-05-05 20:00:00          0.000
# 14800230         1240      0  2016-09-26 12:00:00        138.000
# 4175653          1286      0  2016-03-20 06:00:00        335.330
# AxesSubplot(0.125,0.125;0.698618x0.755)
# --------------------------------------------------
# timestamp start:2016-01-01 00:00:00
# timestamp end:2016-12-31 23:00:00
# --------------------------------------------------
# count of missing values:
# building_id      0
# meter            0
# timestamp        0
# meter_reading    0
# dtype: int64
# --------------------------------------------------
# percentage of missing values:
# building_id      0.0
# meter            0.0
# timestamp        0.0
# meter_reading    0.0
# dtype: float64
# --------------------------------------------------
# missing values visualized:

# %%
#test_df
print("count of unique buildings: " + str(len(test_df["building_id"].value_counts())))
data_info(test_df, 0)
# Out:
# count of unique buildings: 1449
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41697600 entries, 0 to 41697599
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   row_id       int64
#  1   building_id  int64
#  2   meter        int64
#  3   timestamp    object
# dtypes: int64(3), object(1)
# memory usage: 1.2+ GB
# None
# --------------------------------------------------
#              row_id   building_id         meter
# count  4.169760e+07  4.169760e+07  4.169760e+07
# mean   2.084880e+07  8.075824e+02  6.642857e-01
# std    1.203706e+07  4.297680e+02  9.278067e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.042440e+07  4.047500e+02  0.000000e+00
# 50%    2.084880e+07  9.000000e+02  0.000000e+00
# 75%    3.127320e+07  1.194250e+03  1.000000e+00
# max    4.169760e+07  1.448000e+03  3.000000e+00
# --------------------------------------------------
# sample:
#             row_id  building_id  meter            timestamp
# 15220024  15220024          686      0  2017-07-14 01:00:00
# 10714894  10714894          322      0  2017-12-17 04:00:00
# 8430511    8430511          554      0  2017-01-03 17:00:00
# 11059119  11059119          406      0  2018-02-07 13:00:00
# 18391132  18391132          797      2  2018-11-10 01:00:00
# AxesSubplot(0.125,0.125;0.698618x0.755)
# --------------------------------------------------
# timestamp start:2017-01-01 00:00:00
# timestamp end:2018-12-31 23:00:00
# --------------------------------------------------
# count of missing values:
# row_id         0
# building_id    0
# meter          0
# timestamp      0
# dtype: int64
# --------------------------------------------------
# percentage of missing values:
# row_id         0.0
# building_id    0.0
# meter          0.0
# timestamp      0.0
# dtype: float64
# --------------------------------------------------
# missing values visualized:

# %%
#building_df
print("count of unique site_id`s: " + str(len(building_df["site_id"].value_counts())))
print("count of unique primery_use types: " + str(len(building_df["primary_use"].value_counts())))
data_info(building_df)
# Out:
# count of unique site_id`s: 16
# count of unique primery_use types: 16
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   site_id      1449 non-null   int64
#  1   building_id  1449 non-null   int64
#  2   primary_use  1449 non-null   object
#  3   square_feet  1449 non-null   int64
#  4   year_built   675 non-null    float64
#  5   floor_count  355 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 68.0+ KB
# None
# --------------------------------------------------
#            site_id  building_id    square_feet   year_built  floor_count
# count  1449.000000  1449.000000    1449.000000   675.000000   355.000000
# mean      6.952381   724.000000   92111.776398  1967.957037     3.740845
# std       5.003432   418.434583  110769.950997    31.054030     3.333683
# min       0.000000     0.000000     283.000000  1900.000000     1.000000
# 25%       3.000000   362.000000   23012.000000  1949.000000     1.000000
# 50%       5.000000   724.000000   57673.000000  1970.000000     3.000000
# 75%      13.000000  1086.000000  115676.000000  1995.000000     5.000000
# max      15.000000  1448.000000  875000.000000  2017.000000    26.000000
# --------------------------------------------------
# sample:
#      site_id  building_id      primary_use  square_feet  year_built  \
# 859        8          859  Public services         4000         NaN
# 841        8          841           Office         5680         NaN
# 302        3          302        Education        57100      2015.0
# 633        4          633          Parking        98539      1989.0
# 499        3          499        Education       376507      2011.0
#
#      floor_count
# 859          1.0
# 841          1.0
# 302          NaN
# 633          2.0
# 499          NaN
# AxesSubplot(0.125,0.125;0.698618x0.755)
# --------------------------------------------------
# count of missing values:
# site_id           0
# building_id       0
# primary_use       0
# square_feet       0
# year_built      774
# floor_count    1094
# dtype: int64
# --------------------------------------------------
# percentage of missing values:
# site_id         0.000000
# building_id     0.000000
# primary_use     0.000000
# square_feet     0.000000
# year_built     53.416149
# floor_count    75.500345
# dtype: float64
# --------------------------------------------------
# missing values visualized:

# %%
#weather_df
data_info(weather_df,0)
# Out:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139773 entries, 0 to 139772
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   site_id             139773 non-null  int64
#  1   timestamp           139773 non-null  object
#  2   air_temperature     139718 non-null  float64
#  3   cloud_coverage      70600 non-null   float64
#  4   dew_temperature     139660 non-null  float64
#  5   precip_depth_1_hr   89484 non-null   float64
#  6   sea_level_pressure  129155 non-null  float64
#  7   wind_direction      133505 non-null  float64
#  8   wind_speed          139469 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 9.6+ MB
# None
# --------------------------------------------------
#              site_id  air_temperature  cloud_coverage  dew_temperature  \
# count  139773.000000    139718.000000    70600.000000    139660.000000
# mean        7.478977        14.418106        2.149306         7.350158
# std         4.604744        10.626595        2.599150         9.790235
# min         0.000000       -28.900000        0.000000       -35.000000
# 25%         3.000000         7.200000        0.000000         0.600000
# 50%         7.000000        15.000000        2.000000         8.300000
# 75%        11.000000        22.200000        4.000000        14.400000
# max        15.000000        47.200000        9.000000        26.100000
#
#        precip_depth_1_hr  sea_level_pressure  wind_direction     wind_speed
# count       89484.000000       129155.000000   133505.000000  139469.000000
# mean            0.983047         1016.158038      180.526632       3.560527
# std             8.463678            7.629684      111.523629       2.335874
# min            -1.000000          968.200000        0.000000       0.000000
# 25%             0.000000         1011.800000       80.000000       2.100000
# 50%             0.000000         1016.400000      190.000000       3.100000
# 75%             0.000000         1020.800000      280.000000       5.000000
# max           343.000000         1045.500000      360.000000      19.000000
# --------------------------------------------------
# sample:
#        site_id            timestamp  air_temperature  cloud_coverage  \
# 75527        8  2016-08-16 11:00:00             26.1             2.0
# 14887        1  2016-09-12 00:00:00             12.6             0.0
# 35254        4  2016-01-07 01:00:00             10.6             NaN
# 85640        9  2016-10-10 23:00:00             26.7             0.0
# 48309        5  2016-07-04 01:00:00             11.0             0.0
#
#        dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 75527             25.0                0.0              1020.8            80.0
# 14887             10.8                NaN              1014.8           150.0
# 35254              7.8               -1.0              1005.5           150.0
# 85640              3.9                0.0              1019.2           140.0
# 48309             10.0                NaN                 NaN           360.0
#
#        wind_speed
# 75527         1.5
# 14887         2.6
# 35254         5.1
# 85640         2.1
# 48309         1.0
# AxesSubplot(0.125,0.125;0.698618x0.755)
# --------------------------------------------------
# timestamp start:2016-01-01 00:00:00
# timestamp end:2016-12-31 23:00:00
# --------------------------------------------------
# count of missing values:
# site_id                   0
# timestamp                 0
# air_temperature          55
# cloud_coverage        69173
# dew_temperature         113
# precip_depth_1_hr     50289
# sea_level_pressure    10618
# wind_direction         6268
# wind_speed              304
# dtype: int64
# --------------------------------------------------
# percentage of missing values:
# site_id                0.000000
# timestamp              0.000000
# air_temperature        0.039350
# cloud_coverage        49.489529
# dew_temperature        0.080845
# precip_depth_1_hr     35.979052
# sea_level_pressure     7.596603
# wind_direction         4.484414
# wind_speed             0.217496
# dtype: float64
# --------------------------------------------------
# missing values visualized:

# %%
#weather_test_df
data_info(weather_test_df,0)
# Out:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277243 entries, 0 to 277242
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   site_id             277243 non-null  int64
#  1   timestamp           277243 non-null  object
#  2   air_temperature     277139 non-null  float64
#  3   cloud_coverage      136795 non-null  float64
#  4   dew_temperature     276916 non-null  float64
#  5   precip_depth_1_hr   181655 non-null  float64
#  6   sea_level_pressure  255978 non-null  float64
#  7   wind_direction      264873 non-null  float64
#  8   wind_speed          276783 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 19.0+ MB
# None
# --------------------------------------------------
#              site_id  air_temperature  cloud_coverage  dew_temperature  \
# count  277243.000000    277139.000000   136795.000000    276916.000000
# mean        7.484654        14.276863        2.187317         7.487658
# std         4.616959        10.741605        2.620627        10.153973
# min         0.000000       -28.100000        0.000000       -31.600000
# 25%         3.000000         7.200000        0.000000         0.600000
# 50%         7.000000        15.000000        2.000000         8.400000
# 75%        12.000000        22.200000        4.000000        15.000000
# max        15.000000        48.300000        9.000000        26.700000
#
#        precip_depth_1_hr  sea_level_pressure  wind_direction     wind_speed
# count      181655.000000       255978.000000   264873.000000  276783.000000
# mean            1.095395         1016.195762      180.426023       3.548873
# std             9.163511            7.940392      110.456872       2.317184
# min            -1.000000          972.000000        0.000000       0.000000
# 25%             0.000000         1011.600000       80.000000       2.100000
# 50%             0.000000         1016.300000      190.000000       3.100000
# 75%             0.000000         1020.800000      280.000000       4.600000
# max           597.000000         1050.100000      360.000000      24.200000
# --------------------------------------------------
# sample:
#         site_id            timestamp  air_temperature  cloud_coverage  \
# 218231       12  2018-03-15 01:00:00              7.1             8.0
# 159868        9  2017-06-03 01:00:00             30.0             0.0
# 219079       12  2018-04-19 10:00:00             14.6             7.0
# 67868         3  2018-10-10 15:00:00             25.6             6.0
# 260065       15  2017-01-02 00:00:00             -3.3             0.0
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 218231              6.4                NaN               981.9
# 159868             18.9               -1.0              1009.3
# 219079             10.0                NaN              1021.8
# 67868              21.7                0.0              1019.6
# 260065             -6.7                NaN              1027.4
#
#         wind_direction  wind_speed
# 218231           130.0        11.0
# 159868           120.0         2.1
# 219079           200.0         6.0
# 67868            180.0         3.1
# 260065            80.0         2.1
# AxesSubplot(0.125,0.125;0.698618x0.755)
# --------------------------------------------------
# timestamp start:2017-01-01 00:00:00
# timestamp end:2018-12-31 23:00:00
# --------------------------------------------------
# count of missing values:
# site_id                    0
# timestamp                  0
# air_temperature          104
# cloud_coverage        140448
# dew_temperature          327
# precip_depth_1_hr      95588
# sea_level_pressure     21265
# wind_direction         12370
# wind_speed               460
# dtype: int64
# --------------------------------------------------
# percentage of missing values:
# site_id                0.000000
# timestamp              0.000000
# air_temperature        0.037512
# cloud_coverage        50.658808
# dew_temperature        0.117947
# precip_depth_1_hr     34.478057
# sea_level_pressure     7.670167
# wind_direction         4.461790
# wind_speed             0.165919
# dtype: float64
# --------------------------------------------------
# missing values visualized:

# %%
#count of buildings per usage
sns.countplot(y= building_df.primary_use)
# Out:
# <AxesSubplot:xlabel='count', ylabel='primary_use'>

# %%
#count of buildings per site
sns.countplot(y= building_df.site_id)
print("count of buildings in site 11: " + str(building_df.site_id[building_df.site_id == 11].count()))
print("count of buildings in site  3: " + str(building_df.site_id[building_df.site_id == 3].count()))
# Out:
# count of buildings in site 11: 5
# count of buildings in site  3: 274

# %%
#target variable meter_reading is skewed
plt.figure(figsize=(16,5))
sns.distplot(train_vis_df.meter_reading, hist=False)
plt.show()

# %%
#target variable meter_reading after log transformation
plt.figure(figsize=(16,5))
sns.distplot(np.log1p(train_vis_df.meter_reading))
plt.show()

# %%
#count of meter_readings per meter
train_vis_df.meter.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
#energy consumption per meter
train_vis_df.groupby("meter").meter_reading.sum().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='meter'>

# %%
#meter_readings per building
train_vis_df.plot("building_id", "meter_reading")
# Out:
# <AxesSubplot:xlabel='building_id'>

# %%
#buildings with the most energy consumtion
train_vis_df.groupby("building_id").meter_reading.sum().sort_values(ascending=False)[:5]
# Out:
# building_id
# 1099    3.350620e+10
# 778     4.404114e+08
# 1168    4.286342e+08
# 1197    3.904002e+08
# 1159    3.142415e+08
# Name: meter_reading, dtype: float64

# %%
#visualisation of buildings with most energy consumtion
for x in [1099, 778, 1168, 1197, 1159]:
    one_building_df = train_vis_df[train_vis_df.building_id == x]
    one_building_df.set_index("timestamp", inplace=True)
    one_building_df.resample("D").meter_reading.sum().plot()
    plt.title(f"meter readings building {x}")
    plt.show()

# %%
#suspicious meter_readings from buildings with building_id smaller than 104 and meter = 0 at the beginning of the year
merge_vis_df_1 = merge_vis_df.query('building_id <= 104 & meter == 0')
merge_vis_df_1.plot("timestamp", "meter_reading")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#show correlations of features
corrmat=merge_vis_df.corr()
fig,ax=plt.subplots(figsize=(22,20))
sns.heatmap(corrmat,annot=True,annot_kws={'size': 12})
# Out:
# <AxesSubplot:>

# %% [markdown]
# **data preperation**

# %%
# Original code from https://www.kaggle.com/aitude/ashrae-missing-weather-data-handling by @aitude

def fill_weather_dataset(weather_df):
    
    # Find Missing Dates
    time_format = "%Y-%m-%d %H:%M:%S"
    start_date = datetime.datetime.strptime(weather_df['timestamp'].min(),time_format)
    end_date = datetime.datetime.strptime(weather_df['timestamp'].max(),time_format)
    total_hours = int(((end_date - start_date).total_seconds() + 3600) / 3600)
    hours_list = [(end_date - datetime.timedelta(hours=x)).strftime(time_format) for x in range(total_hours)]

    missing_hours = []
    for site_id in range(16):
        site_hours = np.array(weather_df[weather_df['site_id'] == site_id]['timestamp'])
        new_rows = pd.DataFrame(np.setdiff1d(hours_list,site_hours),columns=['timestamp'])
        new_rows['site_id'] = site_id
        weather_df = pd.concat([weather_df,new_rows])

        weather_df = weather_df.reset_index(drop=True)           

    # Add new Features
    weather_df["datetime"] = pd.to_datetime(weather_df["timestamp"])
    weather_df["day"] = weather_df["datetime"].dt.day
    weather_df["week"] = weather_df["datetime"].dt.week
    weather_df["month"] = weather_df["datetime"].dt.month
    
    # Reset Index for Fast Update
    weather_df = weather_df.set_index(['site_id','day','month'])

    air_temperature_filler = pd.DataFrame(weather_df.groupby(['site_id','day','month'])['air_temperature'].mean(),columns=["air_temperature"])
    weather_df.update(air_temperature_filler,overwrite=False)

    # Step 1
    cloud_coverage_filler = weather_df.groupby(['site_id','day','month'])['cloud_coverage'].mean()
    # Step 2
    cloud_coverage_filler = pd.DataFrame(cloud_coverage_filler.fillna(method='ffill'),columns=["cloud_coverage"])

    weather_df.update(cloud_coverage_filler,overwrite=False)

    due_temperature_filler = pd.DataFrame(weather_df.groupby(['site_id','day','month'])['dew_temperature'].mean(),columns=["dew_temperature"])
    weather_df.update(due_temperature_filler,overwrite=False)

    # Step 1
    sea_level_filler = weather_df.groupby(['site_id','day','month'])['sea_level_pressure'].mean()
    # Step 2
    sea_level_filler = pd.DataFrame(sea_level_filler.fillna(method='ffill'),columns=['sea_level_pressure'])

    weather_df.update(sea_level_filler,overwrite=False)

    wind_direction_filler =  pd.DataFrame(weather_df.groupby(['site_id','day','month'])['wind_direction'].mean(),columns=['wind_direction'])
    weather_df.update(wind_direction_filler,overwrite=False)

    wind_speed_filler =  pd.DataFrame(weather_df.groupby(['site_id','day','month'])['wind_speed'].mean(),columns=['wind_speed'])
    weather_df.update(wind_speed_filler,overwrite=False)

    # Step 1
    precip_depth_filler = weather_df.groupby(['site_id','day','month'])['precip_depth_1_hr'].mean()
    # Step 2
    precip_depth_filler = pd.DataFrame(precip_depth_filler.fillna(method='ffill'),columns=['precip_depth_1_hr'])

    weather_df.update(precip_depth_filler,overwrite=False)

    weather_df = weather_df.reset_index()
    weather_df = weather_df.drop(['datetime','day','week'],axis=1)
        
    return weather_df

# Original code from https://www.kaggle.com/gemartin/load-data-reduce-memory-usage by @gemartin

from pandas.api.types import is_datetime64_any_dtype as is_datetime
from pandas.api.types import is_categorical_dtype

def reduce_mem_usage(df, use_float16=False):
    """
    Iterate through all the columns of a dataframe and modify the data type to reduce memory usage.        
    """
    
    start_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage of dataframe is {:.2f} MB".format(start_mem))
    
    for col in df.columns:
        if is_datetime(df[col]) or is_categorical_dtype(df[col]):
            continue
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if use_float16 and c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype("category")

    end_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage after optimization is: {:.2f} MB".format(end_mem))
    print("Decreased by {:.1f}%".format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
#test and train weather_df fill missing values with mean
#add month
weather_df = fill_weather_dataset(weather_df)
weather_test_df = fill_weather_dataset(weather_test_df)

# %%
#reduce memory usage of all data frames
train_df = reduce_mem_usage(train_df,use_float16=True)
building_df = reduce_mem_usage(building_df,use_float16=True)
weather_df = reduce_mem_usage(weather_df,use_float16=True)
test_df = reduce_mem_usage(test_df,use_float16=True)
building_test_df = building_df
weather_test_df = reduce_mem_usage(weather_test_df,use_float16=True)
# Out:
# Memory usage of dataframe is 616.95 MB
# Memory usage after optimization is: 173.84 MB
# Decreased by 71.8%
# Memory usage of dataframe is 0.07 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 73.9%
# Memory usage of dataframe is 10.72 MB
# Memory usage after optimization is: 2.73 MB
# Decreased by 74.5%
# Memory usage of dataframe is 1272.51 MB
# Memory usage after optimization is: 358.53 MB
# Decreased by 71.8%
# Memory usage of dataframe is 21.39 MB
# Memory usage after optimization is: 5.45 MB
# Decreased by 74.5%

# %%
#set type of timestamp
train_df["timestamp"] = train_df["timestamp"].astype("datetime64")
test_df["timestamp"] = test_df["timestamp"].astype("datetime64")
weather_df["timestamp"] = weather_df["timestamp"].astype("datetime64")
weather_test_df["timestamp"] = weather_test_df["timestamp"].astype("datetime64")

# %%
#merge data frames
train_df = train_df.merge(building_df, left_on='building_id',right_on='building_id',how='left')
train_df = train_df.merge(weather_df,how='left',left_on=['site_id','timestamp'],right_on=['site_id','timestamp'])

test_df = test_df.merge(building_test_df, left_on='building_id',right_on='building_id',how='left')
test_df = test_df.merge(weather_test_df,how='left',left_on=['site_id','timestamp'],right_on=['site_id','timestamp'])

# %%
#drop outlier buildings
train_df.drop(train_df.loc[train_df['building_id']== 1099].index, inplace=True)
train_df.drop(train_df.loc[train_df['building_id']== 778].index, inplace=True)

# %%
#drop columns with to much missing values
del train_df["year_built"]
del train_df["floor_count"]

del test_df["year_built"]
del test_df["floor_count"]

# %%
#drop colums with much correlation to others
del train_df["wind_direction"]
del train_df["dew_temperature"]

del test_df["wind_direction"]
del test_df["dew_temperature"]

# %%
#save row_ids
row_ids = test_df["row_id"]

# %%
#remove zero values in meter 0
train_df = train_df.query('not (building_id <= 104 & meter == 0 & timestamp <= "2016-05-20")')

# %%
#log transformation of the target variable
target = np.log1p(train_df["meter_reading"])

# %%
#drop unnecessary columns
train = train_df.drop(["building_id", 'meter_reading', 'timestamp'], axis = 1)
test = test_df.drop(["row_id","building_id", 'timestamp'], axis = 1)
train.columns
# Out:
# Index(['meter', 'site_id', 'primary_use', 'square_feet', 'month',
#        'air_temperature', 'cloud_coverage', 'precip_depth_1_hr',
#        'sea_level_pressure', 'wind_speed'],
#       dtype='object')

# %%
#create dummy variable
train = pd.get_dummies(train, columns = ['meter', "site_id", "primary_use",'month'])
test = pd.get_dummies(test, columns = ['meter', "site_id", "primary_use",'month'])

# %% [markdown]
# **modeling linear regression**

# %%
#fit linear regression model
model_lr = LinearRegression().fit(train, target)

# %%
#show coefficients
c_df = pd.DataFrame(data = model_lr.coef_, index = train.columns, columns = ['Coefficients'])
c_df
# Out:
#                                            Coefficients
# square_feet                                    0.000007
# air_temperature                               -0.001066
# cloud_coverage                                 0.002156
# precip_depth_1_hr                             -0.000230
# sea_level_pressure                            -0.000546
# wind_speed                                     0.000449
# meter_0                                        0.295850
# meter_1                                       -0.044613
# meter_2                                        0.825892
# meter_3                                       -1.077129
# site_id_0                                      1.796219
# site_id_1                                      0.466594
# site_id_2                                      0.163830
# site_id_3                                     -0.083515
# site_id_4                                     -0.120850
# site_id_5                                     -1.245424
# site_id_6                                     -0.052676
# site_id_7                                     -0.898870
# site_id_8                                     -0.824856
# site_id_9                                     -0.029142
# site_id_10                                    -0.394781
# site_id_11                                    -0.125448
# site_id_12                                    -0.038466
# site_id_13                                     0.191492
# site_id_14                                     1.027172
# site_id_15                                     0.168722
# primary_use_Education                          0.399767
# primary_use_Entertainment/public assembly     -0.127511
# primary_use_Food sales and service             0.661444
# primary_use_Healthcare                         0.153314
# primary_use_Lodging/residential               -0.048445
# primary_use_Manufacturing/industrial           0.932952
# primary_use_Office                             0.037383
# primary_use_Other                             -0.292293
# primary_use_Parking                           -1.583443
# primary_use_Public services                    0.235504
# primary_use_Religious worship                 -1.735834
# primary_use_Retail                            -0.496072
# primary_use_Services                          -0.059404
# primary_use_Technology/science                 0.590122
# primary_use_Utility                            1.668187
# primary_use_Warehouse/storage                 -0.335669
# month_1                                       -0.054564
# month_2                                        0.008960
# month_3                                       -0.023090
# month_4                                       -0.011839
# month_5                                       -0.020888
# month_6                                        0.054420
# month_7                                        0.034357
# month_8                                        0.114384
# month_9                                        0.109158
# month_10                                      -0.133722
# month_11                                      -0.015394
# month_12                                      -0.061781

# %%
#visualise coefficients
c_df.sort_values(by = ["Coefficients"])
c_df.Coefficients.plot(kind='barh', figsize = (15,15))
#plt.savefig('featureimportancelr.png')
# Out:
# <AxesSubplot:>

# %%
#predict test data
results_lr = np.expm1(model_lr.predict(test))

# %%
#save results in dataframe
results_lr_df = pd.DataFrame({"row_id": row_ids, "meter_reading": results_lr})

# %%
#save results as csv
results_lr_df.to_csv("submission_lr.csv", index=False)

# %% [markdown]
# Results from Kaggel: <br>
#
#  Private Score | Public Score
# -------- | --------
# 2.075   | 1.792

# %% [markdown]
# **modeling decision tree**

# %%
#fit decision tree
model_dt = DecisionTreeRegressor(random_state = 42).fit(train, target)

# %%
#show feature importances
fi_dt_df = pd.DataFrame(data = model_dt.feature_importances_, index = train.columns, columns = ['Coefficients'])
fi_dt_df
# Out:
#                                            Coefficients
# square_feet                                    0.398524
# air_temperature                                0.131494
# cloud_coverage                                 0.023163
# precip_depth_1_hr                              0.006447
# sea_level_pressure                             0.045918
# wind_speed                                     0.026453
# meter_0                                        0.018198
# meter_1                                        0.019609
# meter_2                                        0.017118
# meter_3                                        0.022335
# site_id_0                                      0.024397
# site_id_1                                      0.002418
# site_id_2                                      0.007640
# site_id_3                                      0.002689
# site_id_4                                      0.001320
# site_id_5                                      0.010592
# site_id_6                                      0.004793
# site_id_7                                      0.009245
# site_id_8                                      0.001181
# site_id_9                                      0.017765
# site_id_10                                     0.004252
# site_id_11                                     0.000673
# site_id_12                                     0.000900
# site_id_13                                     0.009110
# site_id_14                                     0.035987
# site_id_15                                     0.010451
# primary_use_Education                          0.020657
# primary_use_Entertainment/public assembly      0.011735
# primary_use_Food sales and service             0.000629
# primary_use_Healthcare                         0.005527
# primary_use_Lodging/residential                0.009335
# primary_use_Manufacturing/industrial           0.000630
# primary_use_Office                             0.011459
# primary_use_Other                              0.003449
# primary_use_Parking                            0.002999
# primary_use_Public services                    0.005366
# primary_use_Religious worship                  0.000148
# primary_use_Retail                             0.001988
# primary_use_Services                           0.003763
# primary_use_Technology/science                 0.000638
# primary_use_Utility                            0.001513
# primary_use_Warehouse/storage                  0.001613
# month_1                                        0.004829
# month_2                                        0.003925
# month_3                                        0.004842
# month_4                                        0.005808
# month_5                                        0.004733
# month_6                                        0.003530
# month_7                                        0.003771
# month_8                                        0.004547
# month_9                                        0.005149
# month_10                                       0.010136
# month_11                                       0.007796
# month_12                                       0.006812

# %%
#visualise feature importances
fi_dt_df.sort_values(by = ["Coefficients"])
fi_dt_df.Coefficients.plot(kind='barh', figsize = (15,15))
#plt.savefig('featureimportancedt.png')
# Out:
# <AxesSubplot:>

# %%
#predict test data
results_dt = np.expm1(model_dt.predict(test))

# %%
#save results in dataframe
results_dt_df = pd.DataFrame({"row_id": row_ids, "meter_reading": results_dt})

# %%
#save results as csv
results_dt_df.to_csv("submission_dt.csv", index=False)

# %% [markdown]
# Results from Kaggel: <br>
#
# Private Score | Public Score
# -------- | --------
# 1.770   | 1.522

# %% [markdown]
# **modeling random forest**

# %%
#fit random forest (with n_estimators = {5, 10, 20, 40})
model_fr = RandomForestRegressor(n_estimators = 40, n_jobs = -1).fit(train, target)

# %%
#show feature importances
fi_rf_df = pd.DataFrame(data = model_fr.feature_importances_, index = train.columns, columns = ['Coefficients'])
fi_rf_df
# Out:
#                                            Coefficients
# square_feet                                    0.395572
# air_temperature                                0.131091
# cloud_coverage                                 0.022775
# precip_depth_1_hr                              0.006540
# sea_level_pressure                             0.046108
# wind_speed                                     0.026949
# meter_0                                        0.018910
# meter_1                                        0.021408
# meter_2                                        0.020370
# meter_3                                        0.022036
# site_id_0                                      0.024317
# site_id_1                                      0.002864
# site_id_2                                      0.007278
# site_id_3                                      0.002874
# site_id_4                                      0.001473
# site_id_5                                      0.010574
# site_id_6                                      0.004173
# site_id_7                                      0.009401
# site_id_8                                      0.001307
# site_id_9                                      0.017391
# site_id_10                                     0.004202
# site_id_11                                     0.000609
# site_id_12                                     0.000923
# site_id_13                                     0.008014
# site_id_14                                     0.035095
# site_id_15                                     0.011459
# primary_use_Education                          0.019565
# primary_use_Entertainment/public assembly      0.010854
# primary_use_Food sales and service             0.000590
# primary_use_Healthcare                         0.006203
# primary_use_Lodging/residential                0.008865
# primary_use_Manufacturing/industrial           0.000912
# primary_use_Office                             0.012114
# primary_use_Other                              0.003387
# primary_use_Parking                            0.003079
# primary_use_Public services                    0.004991
# primary_use_Religious worship                  0.000197
# primary_use_Retail                             0.001478
# primary_use_Services                           0.003252
# primary_use_Technology/science                 0.000723
# primary_use_Utility                            0.001405
# primary_use_Warehouse/storage                  0.001642
# month_1                                        0.004979
# month_2                                        0.004092
# month_3                                        0.004940
# month_4                                        0.005764
# month_5                                        0.004774
# month_6                                        0.003652
# month_7                                        0.003924
# month_8                                        0.004613
# month_9                                        0.005355
# month_10                                       0.010306
# month_11                                       0.007777
# month_12                                       0.006857

# %%
#visualise feature importances
fi_rf_df.sort_values(by = ["Coefficients"])
fi_rf_df.Coefficients.plot(kind='barh', figsize = (15,15))
plt.savefig('featureimportancerf.png')

# %%
#predict test data
results_fr = np.expm1(model_fr.predict(test))

# %%
#save results in dataframe
results_fr_df = pd.DataFrame({"row_id": row_ids, "meter_reading": results_fr})

# %%
#save results as csv
results_fr_df.to_csv("submission_rf.csv", index=False)

# %% [markdown]
# Results from Kaggel: <br>
#
# n_estimators | Private Score | Public Score
# -------- | -------- | --------
# 5  | 1.645   | 1.380
# 10   | 1.624   | 1.360
# 20  | 1.613   | 1.350
# 40   | 1.611   | 1.345

# %%
#random forest Private Score results visualisation
plt.figure(figsize=(10,10))
plt.plot([5, 10, 20, 40], [1.645, 1.624, 1.613, 1.611])
plt.xlabel("n_estimators") 
plt.ylabel("RSMLE") 
plt.show()

# %%
#random forest Public Score results visualisation
plt.figure(figsize=(10,10))
plt.plot([5, 10, 20, 40], [1.380, 1.360, 1.350, 1.345])
plt.xlabel("n_estimators") 
plt.ylabel("RSMLE") 
plt.show()
